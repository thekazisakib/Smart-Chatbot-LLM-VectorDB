# %%
from langchain import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Pinecone
from langchain.document_loaders import JSONLoader , DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import PromptTemplate
from langchain.llms import CTransformers

# %%
import json
import os

class JSONLoader:
    def __init__(self, file_path):
        self.file_path = file_path

    def load(self):
        with open(self.file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)
        return data

class DirectoryLoader:
    def __init__(self, directory_path):
        self.directory_path = directory_path

    def load_all(self):
        json_data = {}
        for file_name in os.listdir(self.directory_path):
            if file_name.endswith('.json'):
                loader = JSONLoader(os.path.join(self.directory_path, file_name))
                json_data[file_name] = loader.load()
        return json_data

if __name__ == "__main__":
    # Load a specific JSON file using the full path
    jewel_loader = JSONLoader(r'C:\Ml Project\Smart-Chatbot-LLM-VectorDB\data\jewel_changi_content.json')
    jewel_data = jewel_loader.load()
    print("Loaded jewel_changi_content.json:")
    print(jewel_data)
# Out:
# Loaded jewel_changi_content.json:
# ['[Advisory] There will be no Light & Music Showcase from 3 to 9 January due to the annual maintenance works.', '[Advisory] The following attractions will be closed from 3 to 9 January 2025:', 'Other attractions continue to remain open and tickets can be purchased here.', 'Attractions', 'Getting to/from Jewel', "Traveller's Information", 'Amenities & Services', 'Changi Lounge', 'Tax Refund at Jewel', 'Itinerary at Jewel', 'Plants at Jewel', 'Jewel Privileges Programme / Tourist Perks', 'Jewel Vouchers', 'Changi Rewards e-Voucher Flexi', 'eCapitaVoucher', 'Jewel Guided Tour', 'Jewel Beleafers Volunteer Programme', 'Shopping & Dining Promotions', 'Canopy Park Promotions', 'Weddings at Jewel', 'Venue Hire', 'Jewel-rassic Quest', 'Walking Net\nWalking Net - Jewel Changi Airport', 'Bouncing Net\nBouncing Net - Jewel Changi Airport', 'Mirror Maze\nMirror Maze - Jewel Changi Airport', 'Hedge Maze\nHedge Maze - Jewel Changi Airport', 'Mastercard® Canopy Bridge\nMastercard® Canopy Bridge - Jewel Changi Airport', 'Discovery Slides\nDiscovery Slides - Jewel Changi Airport', 'Changi Experience Studio \nChangi Experience Studio - Jewel Changi Airport', 'Jewel Rain Vortex\nJewel Rain Vortex - Jewel Changi Airport', 'Canopy Park\nCanopy Park - Jewel Changi Airport', 'Shiseido Forest Valley\nShiseido Forest Valley - Jewel Changi Airport', 'Foggy Bowls\nFoggy Bowls - Jewel Changi Airport', 'Enjoy exclusive offers & deals at Jewel', 'View More', 'Enjoy exclusive offers & deals at Jewel', 'View More', 'Relax, rejuvenate and be refreshed at the first YOTELAIR Hotel in Asia.', 'View More', 'The ONLY mall in Singapore serving up to 3.5 % rebate - HIGHEST cashback reward at Jewel Changi Airport! Terms apply.', 'View more', 'An exclusive programme for selected Changi Rewards Platinum members', 'View more', 'Explore the special gift boxes that Captain Mickey Mouse has placed around Canopy Park, each unveiling a festive displays and interactive installations inspired by the seven themed areas onboard the all-new Disney Adventure.', 'Discover a wondrous world where nature meets retail', 'Discover a wondrous world where nature meets retail', 'The first-of-its-kind play attractions at Jewel promise endless fun for the young and young at heart!', 'Indulge in the wide array of dining options at Jewel!', 'A world-class shopping experience awaits you at Jewel!', 'Relax, rejuvenate and be refreshed at the first YOTELAIR\xa0Hotel in Asia!', 'Purchase Tickets for Canopy Park and the attractions', 'Explore the special gift boxes that Captain Mickey Mouse has placed around Canopy Park, each unveiling a festive displays and interactive installations inspired by the seven themed areas onboard the all-new Disney Adventure.\xa0\n\xa0\nAlso, get to redeem $80 tenant vouchers with min spend when you shop in Jewel!', 'Explore the special gift boxes that Captain Mickey Mouse has placed around Canopy Park, each unveiling a festive displays and interactive installations inspired by the seven themed areas onboard the all-new Disney Adventure.', 'Also, get to redeem $80 tenant vouchers with min spend when you shop in Jewel!', 'Grab the latest deals', 'View more', 'Grab the latest deals', 'View more', 'Exclusive programmes at Jewel', 'View more', 'Exclusive programmes at Jewel', 'View more', "Step out of the airport right into a lush green sanctuary, a tranquil retreat in the core of the world's best transport hub.\xa0Jewel houses more than 2,000 trees and palms, and over 10,000 shrubs covering a total area of more than 21,000sqm. There are some 120 species, originating from countries all around the globe.\n\xa0\nLearn more about the plants at Jewel today!", "Step out of the airport right into a lush green sanctuary, a tranquil retreat in the core of the world's best transport hub.\xa0Jewel houses more than 2,000 trees and palms, and over 10,000 shrubs covering a total area of more than 21,000sqm. There are some 120 species, originating from countries all around the globe.", ' ...

# %%
from langchain.docstore.document import Document

# Convert list of strings to a list of Document objects
documents = [Document(page_content=item) for item in jewel_data]

# Verify the results
for doc in documents:
    print(doc.page_content)
# Out:
# [Advisory] There will be no Light & Music Showcase from 3 to 9 January due to the annual maintenance works.
# [Advisory] The following attractions will be closed from 3 to 9 January 2025:
# Other attractions continue to remain open and tickets can be purchased here.
# Attractions
# Getting to/from Jewel
# Traveller's Information
# Amenities & Services
# Changi Lounge
# Tax Refund at Jewel
# Itinerary at Jewel
# Plants at Jewel
# Jewel Privileges Programme / Tourist Perks
# Jewel Vouchers
# Changi Rewards e-Voucher Flexi
# eCapitaVoucher
# Jewel Guided Tour
# Jewel Beleafers Volunteer Programme
# Shopping & Dining Promotions
# Canopy Park Promotions
# Weddings at Jewel
# Venue Hire
# Jewel-rassic Quest
# Walking Net
# Walking Net - Jewel Changi Airport
# Bouncing Net
# Bouncing Net - Jewel Changi Airport
# Mirror Maze
# Mirror Maze - Jewel Changi Airport
# Hedge Maze
# Hedge Maze - Jewel Changi Airport
# Mastercard® Canopy Bridge
# Mastercard® Canopy Bridge - Jewel Changi Airport
# Discovery Slides
# Discovery Slides - Jewel Changi Airport
# Changi Experience Studio
# Changi Experience Studio - Jewel Changi Airport
# Jewel Rain Vortex
# Jewel Rain Vortex - Jewel Changi Airport
# Canopy Park
# Canopy Park - Jewel Changi Airport
# Shiseido Forest Valley
# Shiseido Forest Valley - Jewel Changi Airport
# Foggy Bowls
# Foggy Bowls - Jewel Changi Airport
# Enjoy exclusive offers & deals at Jewel
# View More
# Enjoy exclusive offers & deals at Jewel
# View More
# Relax, rejuvenate and be refreshed at the first YOTELAIR Hotel in Asia.
# View More
# The ONLY mall in Singapore serving up to 3.5 % rebate - HIGHEST cashback reward at Jewel Changi Airport! Terms apply.
# View more
# An exclusive programme for selected Changi Rewards Platinum members
# View more
# Explore the special gift boxes that Captain Mickey Mouse has placed around Canopy Park, each unveiling a festive displays and interactive installations inspired by the seven themed areas onboard the all-new Disney Adventure.
# Discover a wondrous world where nature meets retail
# Discover a wondrous world where nature meets retail
# The first-of-its-kind play attractions at Jewel promise endless fun for the young and young at heart!
# Indulge in the wide array of dining options at Jewel!
# A world-class shopping experience awaits you at Jewel!
# Relax, rejuvenate and be refreshed at the first YOTELAIR Hotel in Asia!
# Purchase Tickets for Canopy Park and the attractions
# Explore the special gift boxes that Captain Mickey Mouse has placed around Canopy Park, each unveiling a festive displays and interactive installations inspired by the seven themed areas onboard the all-new Disney Adventure.
#
# Also, get to redeem $80 tenant vouchers with min spend when you shop in Jewel!
# Explore the special gift boxes that Captain Mickey Mouse has placed around Canopy Park, each unveiling a festive displays and interactive installations inspired by the seven themed areas onboard the all-new Disney Adventure.
# Also, get to redeem $80 tenant vouchers with min spend when you shop in Jewel!
# Grab the latest deals
# View more
# Grab the latest deals
# View more
# Exclusive programmes at Jewel
# View more
# Exclusive programmes at Jewel
# View more
# Step out of the airport right into a lush green sanctuary, a tranquil retreat in the core of the world's best transport hub. Jewel houses more than 2,000 trees and palms, and over 10,000 shrubs covering a total area of more than 21,000sqm. There are some 120 species, originating from countries all around the globe.
#
# Learn more about the plants at Jewel today!
# Step out of the airport right into a lush green sanctuary, a tranquil retreat in the core of the world's best transport hub. Jewel houses more than 2,000 trees and palms, and over 10,000 shrubs covering a total area of more than 21,000sqm. There are some 120 species, originating from countries all around the globe.
# Learn more about the plants at Jewel today!
# WELCOME TO JEWEL CHANGI AIRPORT
# Watch the video to find out more
# WELCOME TO JEWEL CHANGI AIRPORT
# Watch the video to find out more
# STAY UPDATED
# Sign up for Jewel's Newsletter
# 78 AIRPORT BOULEVARD, SINGAPORE 819666 ©2024 JEWEL CHANGI AIRPORT DEVT PTE. LTD.
# Conditions of Use
# Privacy Policy
# Your email has been subscribed for newsletter.
# Sorry! Your email is already subscribed.
# By using this site, you agree to our Privacy Policy, Conditions of Access and Cookie Policy to the placement of cookies on your computer.

# %%
def text_split(documents):
    # Filter out documents with None or empty page_content
    valid_documents = [doc for doc in documents if doc.page_content and doc.page_content.strip()]
    if not valid_documents:
        print("No valid documents found. Ensure your input data is correct.")
        return []
    
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=20)
    text_chunks = text_splitter.split_documents(valid_documents)
    return text_chunks

# %%
text_chunks = text_split(documents)

if not text_chunks:
    print("No chunks were created. Please check the input documents.")
else:
    print(f"Number of text chunks created: {len(text_chunks)}")
    for i, chunk in enumerate(text_chunks):
        print(f"Chunk {i+1}: {chunk.page_content[:100] if chunk.page_content else '[Empty or None]'}")
# Out:
# Number of text chunks created: 75
# Chunk 1: [Advisory] There will be no Light & Music Showcase from 3 to 9 January due to the annual maintenance
# Chunk 2: [Advisory] The following attractions will be closed from 3 to 9 January 2025:
# Chunk 3: Other attractions continue to remain open and tickets can be purchased here.
# Chunk 4: Attractions
# Chunk 5: Getting to/from Jewel
# Chunk 6: Traveller's Information
# Chunk 7: Amenities & Services
# Chunk 8: Changi Lounge
# Chunk 9: Tax Refund at Jewel
# Chunk 10: Itinerary at Jewel
# Chunk 11: Plants at Jewel
# Chunk 12: Jewel Privileges Programme / Tourist Perks
# Chunk 13: Jewel Vouchers
# Chunk 14: Changi Rewards e-Voucher Flexi
# Chunk 15: eCapitaVoucher
# Chunk 16: Jewel Guided Tour
# Chunk 17: Jewel Beleafers Volunteer Programme
# Chunk 18: Shopping & Dining Promotions
# Chunk 19: Canopy Park Promotions
# Chunk 20: Weddings at Jewel
# Chunk 21: Venue Hire
# Chunk 22: Jewel-rassic Quest
# Chunk 23: Walking Net
# Walking Net - Jewel Changi Airport
# Chunk 24: Bouncing Net
# Bouncing Net - Jewel Changi Airport
# Chunk 25: Mirror Maze
# Mirror Maze - Jewel Changi Airport
# Chunk 26: Hedge Maze
# Hedge Maze - Jewel Changi Airport
# Chunk 27: Mastercard® Canopy Bridge
# Mastercard® Canopy Bridge - Jewel Changi Airport
# Chunk 28: Discovery Slides
# Discovery Slides - Jewel Changi Airport
# Chunk 29: Changi Experience Studio
# Changi Experience Studio - Jewel Changi Airport
# Chunk 30: Jewel Rain Vortex
# Jewel Rain Vortex - Jewel Changi Airport
# Chunk 31: Canopy Park
# Canopy Park - Jewel Changi Airport
# Chunk 32: Shiseido Forest Valley
# Shiseido Forest Valley - Jewel Changi Airport
# Chunk 33: Foggy Bowls
# Foggy Bowls - Jewel Changi Airport
# Chunk 34: Enjoy exclusive offers & deals at Jewel
# Chunk 35: View More
# Chunk 36: Enjoy exclusive offers & deals at Jewel
# Chunk 37: View More
# Chunk 38: Relax, rejuvenate and be refreshed at the first YOTELAIR Hotel in Asia.
# Chunk 39: View More
# Chunk 40: The ONLY mall in Singapore serving up to 3.5 % rebate - HIGHEST cashback reward at Jewel Changi Airp
# Chunk 41: View more
# Chunk 42: An exclusive programme for selected Changi Rewards Platinum members
# Chunk 43: View more
# Chunk 44: Explore the special gift boxes that Captain Mickey Mouse has placed around Canopy Park, each unveili
# Chunk 45: Discover a wondrous world where nature meets retail
# Chunk 46: Discover a wondrous world where nature meets retail
# Chunk 47: The first-of-its-kind play attractions at Jewel promise endless fun for the young and young at heart
# Chunk 48: Indulge in the wide array of dining options at Jewel!
# Chunk 49: A world-class shopping experience awaits you at Jewel!
# Chunk 50: Relax, rejuvenate and be refreshed at the first YOTELAIR Hotel in Asia!
# Chunk 51: Purchase Tickets for Canopy Park and the attractions
# Chunk 52: Explore the special gift boxes that Captain Mickey Mouse has placed around Canopy Park, each unveili
# Chunk 53: Explore the special gift boxes that Captain Mickey Mouse has placed around Canopy Park, each unveili
# Chunk 54: Also, get to redeem $80 tenant vouchers with min spend when you shop in Jewel!
# Chunk 55: Grab the latest deals
# Chunk 56: View more
# Chunk 57: Grab the latest deals
# Chunk 58: View more
# Chunk 59: Exclusive programmes at Jewel
# Chunk 60: View more
# Chunk 61: Exclusive programmes at Jewel
# Chunk 62: View more
# Chunk 63: Step out of the airport right into a lush green sanctuary, a tranquil retreat in the core of the wor
# Chunk 64: Step out of the airport right into a lush green sanctuary, a tranquil retreat in the core of the wor
# Chunk 65: Learn more about the plants at Jewel today!
# Chunk 66: WELCOME TO JEWEL CHANGI AIRPORT
# Watch the video to find out more
# Chunk 67: WELCOME TO JEWEL CHANGI AIRPORT
# Chunk 68: Watch the video to find out more
# Chunk 69: STAY UPDATED
# Chunk 70: Sign up for Jewel's Newsletter
# Chunk 71: 78 AIRPORT BOULEVARD, SINGAPORE 819666 ©2024 JEWEL CHANGI AIRPORT DEVT PTE. LTD.
# Chunk 72: Conditions of Use
# Privacy Policy
# Chunk 73: Your email has been subscribed for newsletter.
# Chunk 74: Sorry! Your email is already subscribed.
# Chunk 75: By using this site, you agree to our Privacy Policy, Conditions of Access and Cookie Policy to the p

# %%
for i, chunk in enumerate(text_chunks):
    if not chunk.page_content or not chunk.page_content.strip():
        print(f"Skipping invalid chunk at index {i}")
        continue
    # Process valid chunks

# %%
#download embedding model
def download_hugging_face_embeddings():
    embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
    return embeddings

# %%
embeddings = download_hugging_face_embeddings()

# %%
print(embeddings)
# Out:
# client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# ) model_name='sentence-transformers/all-MiniLM-L6-v2' cache_folder=None model_kwargs={} encode_kwargs={} multi_process=False show_progress=False

# %%
query_result = embeddings.embed_query("Hello Everyone")
print("Length", len(query_result))
# Out:
# Length 384

# %%
query_result
# Out:
# [-0.08075389266014099,
#  0.023716680705547333,
#  0.06925341486930847,
#  0.03541908040642738,
#  -0.04857468232512474,
#  -0.08920742571353912,
#  0.04558877274394035,
#  0.0375569723546505,
#  -0.02888455055654049,
#  0.0018666101386770606,
#  0.009728995151817799,
#  0.03500308841466904,
#  -0.023960722610354424,
#  -0.0029713772237300873,
#  -0.00012323154078330845,
#  0.03204181045293808,
#  -0.01193520613014698,
#  -0.10722782462835312,
#  -0.10799280554056168,
#  0.05302891135215759,
#  -0.03382653743028641,
#  0.05754011869430542,
#  -0.026684366166591644,
#  0.0054557970724999905,
#  -0.05876166746020317,
#  0.008353602141141891,
#  0.05532684177160263,
#  0.020789533853530884,
#  -0.02305750362575054,
#  -0.06735552847385406,
#  -0.026168981567025185,
#  0.016779854893684387,
#  0.11763430386781693,
#  0.018279602751135826,
#  0.004240034148097038,
#  0.09002988040447235,
#  -0.054087020456790924,
#  -0.034506767988204956,
#  -0.01146402582526207,
#  0.020212002098560333,
#  -0.013799658045172691,
#  -0.014243573881685734,
#  -0.049998752772808075,
#  -0.002944706240668893,
#  0.05397994816303253,
#  0.01972302980720997,
#  -0.0014110322808846831,
#  0.005707786418497562,
#  0.14251334965229034,
#  0.006282757967710495,
#  0.004826430696994066,
#  -0.06429712474346161,
#  -0.028342001140117645,
#  0.03717530146241188,
#  0.09146630764007568,
#  0.04638621583580971,
#  -0.028430011123418808,
#  -0.023324599489569664,
#  0.042836111038923264,
#  -0.0032135751098394394,
#  -0.06767166405916214,
#  0.05625348165631294,
#  -0.02338404580950737,
#  0.009875737130641937,
#  0.05701282247900963,
#  -0.05527849495410919,
#  -0.021494712680578232,
#  -0.04899362847208977,
#  -0.022358419373631477,
#  -0.026449432596564293,
#  -0.04774229973554611,
#  -0.014272088184952736,
#  0.006308819632977247,
#  0.08019039034843445,
#  -0.007107156794518232,
#  -0.01954573579132557,
#  0.03150102496147156,
#  0.03828563168644905,
#  0.0041791778057813644,
#  0.026893671602010727,
#  0.050166212022304535,
#  -0.06456079334020615,
#  -0.05130185931921005,
#  -0.004628554452210665,
#  0.006577904336154461,
#  0.01374675054103136,
#  0.05344325676560402,
#  0.08467644453048706,
#  -0.046057622879743576,
#  0.010963856242597103,
#  -0.12074408680200577,
#  0.021564137190580368,
#  0.027114365249872208,
#  0.0009135916479863226,
#  -0.034600723534822464,
#  -0.004007501062005758,
#  0.10302168130874634,
#  -0.0036006132140755653,
#  -0.1463501900434494,
#  0.22331160306930542,
#  0.054268188774585724,
#  0.09731171280145645,
#  -0.002781291725113988,
#  0.05135054886341095,
#  0.01699645072221756,
#  0.04050232470035553,
#  0.006262513343244791,
#  -0.02533901110291481,
#  0.0005623608594760299,
#  -0.015869617462158203,
#  -0.005337504204362631,
#  -0.005758114159107208,
#  -0.011214472353458405,
#  0.009171734564006329,
#  0.06098019331693649,
#  0.006398214492946863,
#  0.0022752725053578615,
#  0.016864048317074776,
#  -0.000193676445633173,
#  -0.007430719677358866,
#  -0.016563722863793373,
#  -0.0037898633163422346,
#  -0.030457276850938797,
#  0.04773051291704178,
#  -0.01756911538541317,
#  0.03458246961236,
#  0.0020291339606046677,
#  -4.903819701558922e-33,
#  0.05712639540433884,
#  -0.004089407157152891,
#  0.050678785890340805,
#  0.13926328718662262,
#  -0.0657818615436554,
#  -0.05185282230377197,
#  -0.09813239425420761,
#  -0.06827620416879654,
#  0.044785916805267334,
#  0.02320987358689308,
#  0.046143632382154465,
#  -0.013292980380356312,
#  -0.10352613031864166,
#  0.04003995284438133,
#  -0.03250586986541748,
#  0.05991722270846367,
#  -0.0536472387611866,
#  0.036284588277339935,
#  -0.01653621532022953,
#  0.051317665725946426,
#  -0.06651625037193298,
#  -0.018810302019119263,
#  -0.03337857127189636,
#  0.08727908134460449,
#  -0.00257381540723145,
#  0.007232178933918476,
#  0.03562088683247566,
#  -0.0767296627163887,
#  0.07467112690210342,
#  0.006867370568215847,
#  0.024502959102392197,
#  -0.06585478782653809,
#  -0.006926586385816336,
#  0.02905542217195034,
#  0.0005636813584715128,
#  0.013173463754355907,
#  0.051869262009859085,
#  -0.04752142354846001,
#  -0.04261012747883797,
#  0.019375750795006752,
#  -0.03367610275745392,
#  0.057327501475811005,
#  0.004501912742853165,
#  -0.0554613396525383,
#  -0.01259590033441782,
#  0.008502468466758728,
#  -0.004225242417305708,
#  0.07252112776041031,
#  0.038540374487638474,
#  0.0012037131236866117,
#  -0.027959516271948814,
#  0.009141666814684868,
#  -0.08109328150749207,
#  0.11954864114522934,
#  -0.03834746405482292,
#  -0.031813621520996094,
#  -0.028115199878811836,
#  -0.041992004960775375,
#  0.02075663022696972,
#  0.09892766177654266,
#  0.05348872020840645,
#  0.09010914713144302,
#  -0.04414135962724686,
#  0.006468034815043211,
#  -0.07097897678613663,
#  -0.006275789812207222,
#  0.0666009783744812,
#  -0.024692507460713387,
#  0.021502073854207993,
#  -0.026962587609887123,
#  -0.01797860488295555,
#  -0.019534893333911896,
#  0.024917148053646088,
#  0.033244721591472626,
#  0.009182717651128769,
#  0.05525142699480057,
#  0.000388092827051878,
#  0.010034285485744476,
#  0.06570371240377426,
#  -0.0678587555885315,
#  0.045617517083883286,
#  0.014201220124959946,
#  -0.003228127956390381,
#  -0.04465065523982048,
#  0.0873439833521843,
#  0.059094443917274475,
#  -0.015108329243957996,
#  -0.07589365541934967,
#  -0.05928526818752289,
#  -0.09034668654203415,
#  -0.0642767995595932,
#  0.014630683697760105,
#  0.08235268294811249,
#  -0.0046034809201955795,
#  -0.07697880268096924,
#  3.275720720077698e-33,
#  0.1060643345117569,
#  0.05533189699053764,
#  -0.05606960505247116,
#  -0.06691961735486984,
#  -0.05522570386528969,
#  0.00688175531104207,
#  -0.025886572897434235,
#  0.06090934947133064,
#  -0.11762523651123047,
#  0.05003981292247772,
#  0.08605343103408813,
#  0.010133287869393826,
#  0.08154314756393433,
#  -0.017339693382382393,
#  0.024400394409894943,
#  0.035067345947027206,
#  0.16773508489131927,
#  0.06939176470041275,
#  0.0025017629377543926,
#  -0.011491588316857815,
#  -0.006565428338944912,
#  0.0007166335126385093,
#  -0.05548104643821716,
#  0.032368022948503494,
#  -0.000639981240965426,
#  -0.056534092873334885,
#  0.04274345934391022,
#  0.07530094683170319,
#  -0.1070265844464302,
#  -0.07012904435396194,
#  0.05936397984623909,
#  0.04986818507313728,
#  -0.034815188497304916,
#  0.005998484790325165,
#  0.025953281670808792,
#  0.027647389099001884,
#  -0.01267101801931858,
#  -0.003907985519617796,
#  0.06792861223220825,
#  -0.055813416838645935,
#  0.025799015536904335,
#  0.04112528637051582,
#  -0.036186378449201584,
#  -0.016774922609329224,
#  -0.05545463413000107,
#  -0.026814285665750504,
#  -0.03150346130132675,
#  -0.001563449390232563,
#  -0.07496336847543716,
#  0.057457085698843,
#  -0.0814967006444931,
#  -0.07826998829841614,
#  0.010829245671629906,
#  0.0016217322554439306,
#  -0.027439873665571213,
#  0.07054827362298965,
#  -0.008827353827655315,
#  -0.037345584481954575,
#  -0.04910080507397652,
#  0.00607245322316885,
#  -0.008993780240416527,
#  0.030504422262310982,
#  0.026703013107180595,
#  0.04269417002797127,
#  -0.048334866762161255,
#  0.0379650816321373,
#  -0.05815665423870087,
#  0.002290444914251566,
#  -0.01183940377086401,
#  -0.07653307914733887,
#  0.013426098972558975,
#  -0.03544310852885246,
#  -0.07213261723518372,
#  0.0022167707793414593,
#  0.010454046539962292,
#  0.013118594884872437,
#  -0.0004381831386126578,
#  -0.007748348172754049,
#  0.0164363831281662,
#  0.024166474118828773,
#  0.005883693695068359,
#  -0.003063811222091317,
#  0.007729015313088894,
#  0.03257213905453682,
#  -0.01155040878802538,
#  -0.02898838371038437,
#  0.1062680035829544,
#  0.02925555594265461,
#  0.02677965722978115,
#  -0.05453729256987572,
#  -0.041953496634960175,
#  -0.002152632921934128,
#  -0.03183871880173683,
#  0.03909184783697128,
#  -0.011864665895700455,
#  -1.705538288376829e-08,
#  -0.026691021397709846,
#  0.1013508215546608,
#  -0.02558060921728611,
#  0.0695912316441536,
#  0.008881626650691032,
#  0.05448296666145325,
#  -0.015508164651691914,
#  -0.018888460472226143,
#  -0.007436075713485479,
#  0.060853734612464905,
#  0.013748676516115665,
#  0.11919436603784561,
#  -0.08603466302156448,
#  -0.062091629952192307,
#  0.07898450642824173,
#  0.0759381651878357,
#  -0.004275815561413765,
#  -0.0025682623963803053,
#  -0.06459016352891922,
#  -0.0525340810418129,
#  -0.009365664795041084,
#  0.014137785881757736,
#  0.03187674656510353,
#  -0.08175048977136612,
#  0.02038944512605667,
#  -0.04656536132097244,
#  -0.03872803971171379,
#  -0.012546886689960957,
#  0.005783241707831621,
#  -0.012433953583240509,
#  -0.03756335750222206,
#  0.06888717412948608,
#  -0.03037445619702339,
#  0.02809515781700611,
#  -0.03902726620435715,
#  -0.029732409864664078,
#  0.021836405619978905,
#  0.0005253741983324289,
#  0.06888187676668167,
#  -0.05024558678269386,
#  -0.12568005919456482,
#  0.006872018799185753,
#  0.009643512777984142,
#  -0.1157536581158638,
#  -0.03931419551372528,
#  0.062370724976062775,
#  0.04982501268386841,
#  -0.07983748614788055,
#  -0.04504408687353134,
#  -0.008618653751909733,
#  -0.015109263360500336,
#  -0.010941323824226856,
#  0.05563148483633995,
#  0.09224417060613632,
#  0.10355397313833237,
#  0.06840994954109192,
#  -0.02749199979007244,
#  -0.046522513031959534,
#  -0.0011127123143523932,
#  -0.06350383907556534,
#  0.0436369925737381,
#  0.04337262362241745,
#  0.05653144791722298,
#  0.019300099462270737]

# %%
from qdrant_client import QdrantClient
from qdrant_client.http import models

# Replace with your Qdrant Cloud API key and endpoint
API_KEY = "id_eSlOhQXSWYlAJIRR7T8gJj4mfN-sA155gJIoOanX8oTCmAg7TLg"  # Removed the comma here
ENDPOINT = "https://3607b9cc-3e8d-4a76-ada5-843a14f7b744.europe-west3-0.gcp.cloud.qdrant.io"

# Initialize Qdrant client
client = QdrantClient(
    url=ENDPOINT,
    api_key=API_KEY
)

# Create or reset collection in Qdrant
collection_name = "my_collection"
vector_size = 384  # Adjust this based on your embedding model's output size

# Define vectors configuration
vectors_config = models.VectorParams(
    size=vector_size,         # Dimension of the vectors
    distance=models.Distance.COSINE  # Similarity metric
)

client.recreate_collection(
    collection_name=collection_name,
    vectors_config=vectors_config
)

print(f"Collection '{collection_name}' created successfully.")
# Out:
# C:\Users\newth\AppData\Local\Temp\ipykernel_14992\1996543962.py:24: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   client.recreate_collection(
# Collection 'my_collection' created successfully.

# %%
import uuid

# Generate embeddings for each chunk of text
for i, document in enumerate(text_chunks):
    text = document.page_content.strip()  # Ensure no leading/trailing whitespace
    if not text:  # Skip if the text is empty
        print(f"Skipping empty text chunk at index {i}")
        continue

    vector = embeddings.embed_query(text)  # Generate embedding for each text
    
    # Generate a unique UUID for each point
    point_id = str(uuid.uuid4())

    client.upsert(
        collection_name=collection_name,
        points=[
            {
                'id': point_id,
                'vector': vector,
                'payload': {'text': text}
            }
        ]
    )

print(f"Embeddings for {len(text_chunks)} text chunks stored in Qdrant successfully.")
# Out:
# Embeddings for 75 text chunks stored in Qdrant successfully.

# %%
# Assuming embeddings and client are already initialized and collection exists

query = "What are the name of Changi Airport Lounge"
query_vector = embeddings.embed_query(query)  # Generate embedding for the query

# Perform similarity search in Qdrant
docs = client.search(
    collection_name=collection_name,
    query_vector=query_vector,
    limit=3
)

# Print the results
for result in docs:
    print(result.payload["text"])  # Assuming the text is in the payload
# Out:
# Changi Lounge
# Canopy Park
# Canopy Park - Jewel Changi Airport
# Hedge Maze
# Hedge Maze - Jewel Changi Airport

# %%
prompt_template="""
Use the following pieces of information to answer the user's question.
If you don't know the answer, just say that you don't know, don't try to make up an answer.

Context: {context}
Question: {question}

Only return the helpful answer below and nothing else.
Helpful answer:
"""

# %%
PROMPT=PromptTemplate(template=prompt_template, input_variables=["context", "question"])
chain_type_kwargs={"prompt": PROMPT}

# %%
llm = CTransformers(model="C:/Ml Project/Smart-Chatbot-LLM-VectorDB/model/llama-2-7b-chat.ggmlv3.q4_0.bin",
                   model_type="llama",
                   config={'max_new_tokens': 512, 'temperature': 0.8})

# %%
from langchain.vectorstores import Qdrant
from langchain.chains import RetrievalQA

# Create a retriever using the Qdrant vector store
retriever = Qdrant(
    client=client,
    collection_name=collection_name,
    embeddings=embeddings  # Use the same embeddings model as above
).as_retriever(search_kwargs={'k': 2})

# Initialize RetrievalQA
qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",  # Combining retrieved documents
    retriever=retriever,
    chain_type_kwargs=chain_type_kwargs
)

# %%
while True:
    user_input = input("Input Prompt: ")
    if user_input.lower() in ["exit", "quit"]:
        print("Exiting...")
        break

    if not user_input.strip():  # Check for empty input
        print("Please enter a valid prompt.")
        continue

    try:
        # Pass the user input to the QA system
        result = qa.run({"query": user_input})

        if not result:  # Handle cases where no response is generated
            print("No response generated. Please try again.")
        else:
            print("Response:", result)
    except ValueError as ve:
        print(f"Value Error: {ve}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
# Out:
# Value Error: 1 validation error for Document
# page_content
#   none is not an allowed value (type=type_error.none.not_allowed)
# Exiting...

# %%
# Query and get the result
query = "What are the names of Changi Airport Lounges?"
result = qa.run(query)

# Print result
print(result)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[112], line 3
#       1 # Query and get the result
#       2 query = "What are the names of Changi Airport Lounges?"
# ----> 3 result = qa.run(query)
#       5 # Print result
#       6 print(result)
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\langchain_core\_api\deprecation.py:180, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     178     warned = True
#     179     emit_warning()
# --> 180 return wrapped(*args, **kwargs)
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\langchain\chains\base.py:597, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     595     if len(args) != 1:
#     596         raise ValueError("`run` supports only one positional argument.")
# --> 597     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     598         _output_key
#     599     ]
#     601 if kwargs and not args:
#     602     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     603         _output_key
#     604     ]
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\langchain_core\_api\deprecation.py:180, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     178     warned = True
#     179     emit_warning()
# --> 180 return wrapped(*args, **kwargs)
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\langchain\chains\base.py:380, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     348 """Execute the chain.
#     349
#     350 Args:
#    (...)
#     371         `Chain.output_keys`.
#     372 """
#     373 config = {
#     374     "callbacks": callbacks,
#     375     "tags": tags,
#     376     "metadata": metadata,
#     377     "run_name": run_name,
#     378 }
# --> 380 return self.invoke(
#     381     inputs,
#     382     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     383     return_only_outputs=return_only_outputs,
#     384     include_run_info=include_run_info,
#     385 )
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\langchain\chains\base.py:163, in Chain.invoke(self, input, config, **kwargs)
#     161 except BaseException as e:
#     162     run_manager.on_chain_error(e)
# --> 163     raise e
#     164 run_manager.on_chain_end(outputs)
#     166 if include_run_info:
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\langchain\chains\base.py:153, in Chain.invoke(self, input, config, **kwargs)
#     150 try:
#     151     self._validate_inputs(inputs)
#     152     outputs = (
# --> 153         self._call(inputs, run_manager=run_manager)
#     154         if new_arg_supported
#     155         else self._call(inputs)
#     156     )
#     158     final_outputs: Dict[str, Any] = self.prep_outputs(
#     159         inputs, outputs, return_only_outputs
#     160     )
#     161 except BaseException as e:
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\langchain\chains\retrieval_qa\base.py:150, in BaseRetrievalQA._call(self, inputs, run_manager)
#     146 accepts_run_manager = (
#     147     "run_manager" in inspect.signature(self._get_docs).parameters
#     148 )
#     149 if accepts_run_manager:
# --> 150     docs = self._get_docs(question, run_manager=_run_manager)
#     151 else:
#     152     docs = self._get_docs(question)  # type: ignore[call-arg]
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\langchain\chains\retrieval_qa\base.py:270, in RetrievalQA._get_docs(self, question, run_manager)
#     263 def _get_docs(
#     264     self,
#     265     question: str,
#     266     *,
#     267     run_manager: CallbackManagerForChainRun,
#     268 ) -> List[Document]:
#     269     """Get docs."""
# --> 270     return self.retriever.invoke(
#     271         question, config={"callbacks": run_manager.get_child()}
#     272     )
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\langchain_core\retrievers.py:252, in BaseRetriever.invoke(self, input, config, **kwargs)
#     250 except Exception as e:
#     251     run_manager.on_retriever_error(e)
# --> 252     raise e
#     253 else:
#     254     run_manager.on_retriever_end(
#     255         result,
#     256     )
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\langchain_core\retrievers.py:245, in BaseRetriever.invoke(self, input, config, **kwargs)
#     243 _kwargs = kwargs if self._expects_other_args else {}
#     244 if self._new_arg_supported:
# --> 245     result = self._get_relevant_documents(
#     246         input, run_manager=run_manager, **_kwargs
#     247     )
#     248 else:
#     249     result = self._get_relevant_documents(input, **_kwargs)
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\langchain_core\vectorstores\base.py:1042, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager)
#    1038 def _get_relevant_documents(
#    1039     self, query: str, *, run_manager: CallbackManagerForRetrieverRun
#    1040 ) -> List[Document]:
#    1041     if self.search_type == "similarity":
# -> 1042         docs = self.vectorstore.similarity_search(query, **self.search_kwargs)
#    1043     elif self.search_type == "similarity_score_threshold":
#    1044         docs_and_similarities = (
#    1045             self.vectorstore.similarity_search_with_relevance_scores(
#    1046                 query, **self.search_kwargs
#    1047             )
#    1048         )
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\langchain_community\vectorstores\qdrant.py:288, in Qdrant.similarity_search(self, query, k, filter, search_params, offset, score_threshold, consistency, **kwargs)
#     243 def similarity_search(
#     244     self,
#     245     query: str,
#    (...)
#     252     **kwargs: Any,
#     253 ) -> List[Document]:
#     254     """Return docs most similar to query.
#     255
#     256     Args:
#    (...)
#     286         List of Documents most similar to the query.
#     287     """
# --> 288     results = self.similarity_search_with_score(
#     289         query,
#     290         k,
#     291         filter=filter,
#     292         search_params=search_params,
#     293         offset=offset,
#     294         score_threshold=score_threshold,
#     295         consistency=consistency,
#     296         **kwargs,
#     297     )
#     298     return list(map(itemgetter(0), results))
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\langchain_community\vectorstores\qdrant.py:364, in Qdrant.similarity_search_with_score(self, query, k, filter, search_params, offset, score_threshold, consistency, **kwargs)
#     319 def similarity_search_with_score(
#     320     self,
#     321     query: str,
#    (...)
#     328     **kwargs: Any,
#     329 ) -> List[Tuple[Document, float]]:
#     330     """Return docs most similar to query.
#     331
#     332     Args:
#    (...)
#     362         List of documents most similar to the query text and distance for each.
#     363     """
# --> 364     return self.similarity_search_with_score_by_vector(
#     365         self._embed_query(query),
#     366         k,
#     367         filter=filter,
#     368         search_params=search_params,
#     369         offset=offset,
#     370         score_threshold=score_threshold,
#     371         consistency=consistency,
#     372         **kwargs,
#     373     )
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\langchain_community\vectorstores\qdrant.py:623, in Qdrant.similarity_search_with_score_by_vector(self, embedding, k, filter, search_params, offset, score_threshold, consistency, **kwargs)
#     608     query_vector = (self.vector_name, embedding)  # type: ignore[assignment]
#     610 results = self.client.search(
#     611     collection_name=self.collection_name,
#     612     query_vector=query_vector,
#    (...)
#     621     **kwargs,
#     622 )
# --> 623 return [
#     624     (
#     625         self._document_from_scored_point(
#     626             result,
#     627             self.collection_name,
#     628             self.content_payload_key,
#     629             self.metadata_payload_key,
#     630         ),
#     631         result.score,
#     632     )
#     633     for result in results
#     634 ]
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\langchain_community\vectorstores\qdrant.py:625, in <listcomp>(.0)
#     608     query_vector = (self.vector_name, embedding)  # type: ignore[assignment]
#     610 results = self.client.search(
#     611     collection_name=self.collection_name,
#     612     query_vector=query_vector,
#    (...)
#     621     **kwargs,
#     622 )
#     623 return [
#     624     (
# --> 625         self._document_from_scored_point(
#     626             result,
#     627             self.collection_name,
#     628             self.content_payload_key,
#     629             self.metadata_payload_key,
#     630         ),
#     631         result.score,
#     632     )
#     633     for result in results
#     634 ]
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\langchain_community\vectorstores\qdrant.py:2008, in Qdrant._document_from_scored_point(cls, scored_point, collection_name, content_payload_key, metadata_payload_key)
#    2006 metadata["_id"] = scored_point.id
#    2007 metadata["_collection_name"] = collection_name
# -> 2008 return Document(
#    2009     page_content=scored_point.payload.get(content_payload_key),
#    2010     metadata=metadata,
#    2011 )
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\langchain_core\documents\base.py:270, in Document.__init__(self, page_content, **kwargs)
#     267 """Pass page_content in as positional or named arg."""
#     268 # my-py is complaining that page_content is not defined on the base class.
#     269 # Here, we're relying on pydantic base class to handle the validation.
# --> 270 super().__init__(page_content=page_content, **kwargs)
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\langchain_core\load\serializable.py:113, in Serializable.__init__(self, *args, **kwargs)
#     111 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     112     """"""
# --> 113     super().__init__(*args, **kwargs)
#
# File c:\Users\newth\miniconda3\envs\chatbot\lib\site-packages\pydantic\v1\main.py:341, in BaseModel.__init__(__pydantic_self__, **data)
#     339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
# --> 341     raise validation_error
#     342 try:
#     343     object_setattr(__pydantic_self__, '__dict__', values)
#
# ValidationError: 1 validation error for Document
# page_content
#   none is not an allowed value (type=type_error.none.not_allowed)
